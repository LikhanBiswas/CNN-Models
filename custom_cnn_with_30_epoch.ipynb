# %% [markdown]
# <a href="https://colab.research.google.com/github/LikhanBiswas/CNN-Models/blob/main/custom_cnn_with_30_epoch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Aug 26 13:55:04 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8    26W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Model
from keras import models
import keras
from keras import regularizers

# %%
my_model= models.Sequential()

# %%
# Add first convolutional block
my_model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(215,215,3)))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))

# second block
my_model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2),strides=(2,2), padding='same'))
# third block
my_model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
# fourth block
my_model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
#fifth block
my_model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
#sixth block
my_model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
#seventh block
my_model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))

# %%
my_model.add(GlobalAveragePooling2D())
# fully connected layer
my_model.add(Dense(64, activation='relu'))
my_model.add(BatchNormalization())
# make predictions
my_model.add(Dense(1, activation='sigmoid'))

# %%
# Show a summary of the model. Check the number of trainable parameters
my_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 215, 215, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 108, 108, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 54, 54, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 27, 27, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 27, 27, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                32832
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 7,805,921
# Trainable params: 7,805,793
# Non-trainable params: 128
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(my_model, to_file='model_plot.png', show_shapes=True, show_layer_names=True, dpi = 60)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
es=EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

# save best model automatically
#mc= ModelCheckpoint('/content/drive/MyDrive/extension/custom_cnn.h5', monitor='val_loss', 
                    #mode='min', verbose=1, save_best_only=True)
#cb_list=[es,mc]

# %%
for layer in my_model.layers:
    layer.kernel_regularizer = keras.regularizers.l1_l2(0.01)

# %%
my_model.compile(optimizer='adam', loss='binary_crossentropy', 
                 metrics=['accuracy'])

# %%
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator

# set up data generator
data_generator = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_path = '/content/drive/MyDrive/real vs fake/NEW_TRAIN_10K'
valid_path = '/content/drive/MyDrive/real vs fake/test'

# %%
data_generator = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.1,
                                   zoom_range=0.1,
                                   rotation_range=90,
                                   width_shift_range=0.1,
                                   #fill_mode='wrap',
                                   height_shift_range=0.1,
                                   #channel_shift_range=150.0,
                                   brightness_range=(0.1, 0.5),
                                   vertical_flip=True,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# get batches of training images from the directory
train_generator = data_generator.flow_from_directory(
        '/content/drive/MyDrive/real vs fake/NEW_TRAIN_10K',
        target_size=(215, 215),
        batch_size=32,
        color_mode='rgb',
        class_mode='binary')

# get batches of validation images from the directory
validation_generator = test_datagen.flow_from_directory(
        '/content/drive/MyDrive/real vs fake/test',
        target_size=(215, 215),
        batch_size=32,
        color_mode='rgb',
        class_mode='binary')
# Out:
# Found 10000 images belonging to 2 classes.
# Found 3000 images belonging to 2 classes.

# %%
history = my_model.fit(
        train_generator,
        epochs=30,
        steps_per_epoch=len(train_generator),
        validation_data=validation_generator,
        validation_steps=93)
# Out:
# Epoch 1/30
# 313/313 [==============================] - 3731s 12s/step - loss: 0.1991 - accuracy: 0.9244 - val_loss: 2.2597 - val_accuracy: 0.5017
# Epoch 2/30
# 313/313 [==============================] - 166s 531ms/step - loss: 0.0519 - accuracy: 0.9833 - val_loss: 19.4240 - val_accuracy: 0.5000
# Epoch 3/30
# 313/313 [==============================] - 165s 527ms/step - loss: 0.0404 - accuracy: 0.9861 - val_loss: 0.3436 - val_accuracy: 0.8942
# Epoch 4/30
# 313/313 [==============================] - 162s 518ms/step - loss: 0.0350 - accuracy: 0.9887 - val_loss: 0.0593 - val_accuracy: 0.9795
# Epoch 5/30
# 313/313 [==============================] - 162s 517ms/step - loss: 0.0245 - accuracy: 0.9917 - val_loss: 0.1442 - val_accuracy: 0.9459
# Epoch 6/30
# 313/313 [==============================] - 163s 522ms/step - loss: 0.0326 - accuracy: 0.9881 - val_loss: 13.8118 - val_accuracy: 0.4990
# Epoch 7/30
# 313/313 [==============================] - 167s 534ms/step - loss: 0.0238 - accuracy: 0.9918 - val_loss: 0.3549 - val_accuracy: 0.9147
# Epoch 8/30
# 313/313 [==============================] - 168s 537ms/step - loss: 0.0312 - accuracy: 0.9898 - val_loss: 10.3458 - val_accuracy: 0.5013
# Epoch 9/30
# 313/313 [==============================] - 171s 545ms/step - loss: 0.0247 - accuracy: 0.9912 - val_loss: 13.6990 - val_accuracy: 0.5000
# Epoch 10/30
# 313/313 [==============================] - 171s 547ms/step - loss: 0.0306 - accuracy: 0.9899 - val_loss: 11.1371 - val_accuracy: 0.4990
# Epoch 11/30
# 313/313 [==============================] - 170s 543ms/step - loss: 0.0237 - accuracy: 0.9929 - val_loss: 3.2952 - val_accuracy: 0.4990
# Epoch 12/30
# 313/313 [==============================] - 170s 543ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.1455 - val_accuracy: 0.9832
# Epoch 13/30
# 313/313 [==============================] - 170s 543ms/step - loss: 0.0246 - accuracy: 0.9919 - val_loss: 12.2375 - val_accuracy: 0.5010
# Epoch 14/30
# 313/313 [==============================] - 170s 545ms/step - loss: 0.0247 - accuracy: 0.9920 - val_loss: 0.0883 - val_accuracy: 0.9741
# Epoch 15/30
# 313/313 [==============================] - 170s 544ms/step - loss: 0.0237 - accuracy: 0.9914 - val_loss: 0.0238 - val_accuracy: 0.9929
# Epoch 16/30
# 313/313 [==============================] - 170s 543ms/step - loss: 0.0263 - accuracy: 0.9908 - val_loss: 1.0842 - val_accuracy: 0.7060
# Epoch 17/30
# 313/313 [==============================] - 170s 544ms/step - loss: 0.0250 - accuracy: 0.9916 - val_loss: 0.6858 - val_accuracy: 0.8256
# Epoch 18/30
# 313/313 [==============================] - 171s 546ms/step - loss: 0.0154 - accuracy: 0.9945 - val_loss: 0.1306 - val_accuracy: 0.9718
# Epoch 19/30
# 313/313 [==============================] - 171s 546ms/step - loss: 0.0122 - accuracy: 0.9960 - val_loss: 0.5438 - val_accuracy: 0.8696
# Epoch 20/30
# 313/313 [==============================] - 166s 530ms/step - loss: 0.0203 - accuracy: 0.9930 - val_loss: 0.0171 - val_accuracy: 0.9950
# Epoch 21/30
# 313/313 [==============================] - 166s 531ms/step - loss: 0.0169 - accuracy: 0.9945 - val_loss: 0.1472 - val_accuracy: 0.9802
# Epoch 22/30
# 313/313 [==============================] - 166s 530ms/step - loss: 0.0169 - accuracy: 0.9941 - val_loss: 2.4616 - val_accuracy: 0.5309
# Epoch 23/30
# 313/313 [==============================] - 167s 534ms/step - loss: 0.0168 - accuracy: 0.9939 - val_loss: 4.0639 - val_accuracy: 0.4997
# Epoch 24/30
# 313/313 [==============================] - 167s 533ms/step - loss: 0.0208 - accuracy: 0.9923 - val_loss: 3.9622 - val_accuracy: 0.5074
# Epoch 25/30
# 313/313 [==============================] - 167s 534ms/step - loss: 0.0132 - accuracy: 0.9954 - val_loss: 0.1921 - val_accuracy: 0.9291
# Epoch 26/30
# 313/313 [==============================] - 169s 539ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 0.0869 - val_accuracy: 0.9640
# Epoch 27/30
# 313/313 [==============================] - 168s 535ms/step - loss: 0.0156 - accuracy: 0.9948 - val_loss: 0.0340 - val_accuracy: 0.9856
# Epoch 28/30
# 313/313 [==============================] - 168s 536ms/step - loss: 0.0195 - accuracy: 0.9943 - val_loss: 0.3074 - val_accuracy: 0.8962
# Epoch 29/30
# 313/313 [==============================] - 167s 534ms/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 0.0064 - val_accuracy: 0.9987
# Epoch 30/30
# 313/313 [==============================] - 168s 536ms/step - loss: 0.0150 - accuracy: 0.9941 - val_loss: 0.4790 - val_accuracy: 0.8182

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')
