# %% [markdown]
# <a href="https://colab.research.google.com/github/LikhanBiswas/CNN-Models/blob/main/custom_cnn_with_30_epoch(new).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Aug 27 14:46:54 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Model
from keras import models
import keras
from keras import regularizers

# %%
my_model= models.Sequential()

# %%
# Add first convolutional block
my_model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(215,215,3)))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))

# second block
my_model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2),strides=(2,2), padding='same'))
# third block
my_model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
# fourth block
my_model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
#my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
#fifth block
my_model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
#sixth block
my_model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
#seventh block
my_model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))

# %%
my_model.add(GlobalAveragePooling2D())
# fully connected layer
my_model.add(Dense(64, activation='relu'))
my_model.add(BatchNormalization())
# make predictions
my_model.add(Dense(1, activation='sigmoid'))

# %%
# Show a summary of the model. Check the number of trainable parameters
my_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 215, 215, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 108, 108, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 54, 54, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 27, 27, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 27, 27, 128)       73856
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 27, 27, 128)       147584
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 27, 27, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 256)       295168
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 256)       590080
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 14, 14, 256)       590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 7, 7, 512)         1180160
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                32832
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 7,805,921
# Trainable params: 7,805,793
# Non-trainable params: 128
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(my_model, to_file='model_plot.png', show_shapes=True, show_layer_names=True, dpi = 60)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
es=EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

# save best model automatically
#mc= ModelCheckpoint('/content/drive/MyDrive/extension/custom_cnn.h5', monitor='val_loss', 
                    #mode='min', verbose=1, save_best_only=True)
#cb_list=[es,mc]

# %%
for layer in my_model.layers:
    layer.kernel_regularizer = keras.regularizers.l1_l2(0.01)

# %%
my_model.compile(optimizer='adam', loss='binary_crossentropy', 
                 metrics=['accuracy'])

# %%
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator

# set up data generator
data_generator = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_path = '/content/drive/MyDrive/real vs fake/NEW_TRAIN_10K'
valid_path = '/content/drive/MyDrive/real vs fake/test'

# %%
data_generator = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.1,
                                   zoom_range=0.1,
                                   rotation_range=90,
                                   width_shift_range=0.1,
                                   #fill_mode='wrap',
                                   height_shift_range=0.1,
                                   #channel_shift_range=150.0,
                                   brightness_range=(0.1, 0.5),
                                   vertical_flip=True,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# get batches of training images from the directory
train_generator = data_generator.flow_from_directory(
        '/content/drive/MyDrive/real vs fake/NEW_TRAIN_10K',
        target_size=(215, 215),
        batch_size=32,
        color_mode='rgb',
        class_mode='binary')

# get batches of validation images from the directory
validation_generator = test_datagen.flow_from_directory(
        '/content/drive/MyDrive/real vs fake/test',
        target_size=(215, 215),
        batch_size=32,
        color_mode='rgb',
        class_mode='binary')
# Out:
# Found 10000 images belonging to 2 classes.
# Found 3000 images belonging to 2 classes.

# %%
history = my_model.fit(
  train_generator,
  validation_data=validation_generator,
  epochs=30,
  steps_per_epoch=len(train_generator),
  validation_steps=len(validation_generator)
  
)
# Out:
# Epoch 1/30
# 313/313 [==============================] - 3719s 12s/step - loss: 0.2567 - accuracy: 0.9034 - val_loss: 1.6732 - val_accuracy: 0.5030
# Epoch 2/30
# 313/313 [==============================] - 163s 522ms/step - loss: 0.0910 - accuracy: 0.9703 - val_loss: 1.4875 - val_accuracy: 0.5620
# Epoch 3/30
# 313/313 [==============================] - 162s 517ms/step - loss: 0.0435 - accuracy: 0.9852 - val_loss: 0.7041 - val_accuracy: 0.8023
# Epoch 4/30
# 313/313 [==============================] - 165s 528ms/step - loss: 0.0387 - accuracy: 0.9855 - val_loss: 0.2222 - val_accuracy: 0.9173
# Epoch 5/30
# 313/313 [==============================] - 166s 531ms/step - loss: 0.0298 - accuracy: 0.9895 - val_loss: 0.2717 - val_accuracy: 0.8863
# Epoch 6/30
# 313/313 [==============================] - 163s 520ms/step - loss: 0.0265 - accuracy: 0.9918 - val_loss: 0.0158 - val_accuracy: 0.9953
# Epoch 7/30
# 313/313 [==============================] - 167s 533ms/step - loss: 0.0175 - accuracy: 0.9943 - val_loss: 0.0423 - val_accuracy: 0.9850
# Epoch 8/30
# 313/313 [==============================] - 170s 542ms/step - loss: 0.0186 - accuracy: 0.9935 - val_loss: 0.0582 - val_accuracy: 0.9783
# Epoch 9/30
# 313/313 [==============================] - 177s 566ms/step - loss: 0.0203 - accuracy: 0.9938 - val_loss: 1.0806 - val_accuracy: 0.7267
# Epoch 10/30
# 313/313 [==============================] - 176s 562ms/step - loss: 0.0200 - accuracy: 0.9928 - val_loss: 0.3723 - val_accuracy: 0.8820
# Epoch 11/30
# 313/313 [==============================] - 178s 567ms/step - loss: 0.0200 - accuracy: 0.9933 - val_loss: 0.5008 - val_accuracy: 0.8183
# Epoch 12/30
# 313/313 [==============================] - 175s 557ms/step - loss: 0.0164 - accuracy: 0.9951 - val_loss: 0.8757 - val_accuracy: 0.7553
# Epoch 13/30
# 313/313 [==============================] - 174s 557ms/step - loss: 0.0205 - accuracy: 0.9942 - val_loss: 0.0325 - val_accuracy: 0.9890
# Epoch 14/30
# 313/313 [==============================] - 175s 558ms/step - loss: 0.0180 - accuracy: 0.9935 - val_loss: 0.0101 - val_accuracy: 0.9977
# Epoch 15/30
# 313/313 [==============================] - 177s 565ms/step - loss: 0.0188 - accuracy: 0.9930 - val_loss: 0.1488 - val_accuracy: 0.9463
# Epoch 16/30
# 313/313 [==============================] - 177s 564ms/step - loss: 0.0181 - accuracy: 0.9932 - val_loss: 0.0052 - val_accuracy: 0.9990
# Epoch 17/30
# 313/313 [==============================] - 175s 560ms/step - loss: 0.0176 - accuracy: 0.9946 - val_loss: 926.6332 - val_accuracy: 0.5000
# Epoch 18/30
# 313/313 [==============================] - 173s 554ms/step - loss: 0.0122 - accuracy: 0.9951 - val_loss: 0.1181 - val_accuracy: 0.9493
# Epoch 19/30
# 313/313 [==============================] - 173s 554ms/step - loss: 0.0130 - accuracy: 0.9954 - val_loss: 0.0102 - val_accuracy: 0.9980
# Epoch 20/30
# 313/313 [==============================] - 176s 561ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.7838 - val_accuracy: 0.7440
# Epoch 21/30
# 313/313 [==============================] - 176s 561ms/step - loss: 0.0140 - accuracy: 0.9951 - val_loss: 0.0140 - val_accuracy: 0.9950
# Epoch 22/30
# 313/313 [==============================] - 176s 561ms/step - loss: 0.0109 - accuracy: 0.9956 - val_loss: 0.0046 - val_accuracy: 0.9993
# Epoch 23/30
# 313/313 [==============================] - 174s 554ms/step - loss: 0.0112 - accuracy: 0.9964 - val_loss: 0.0135 - val_accuracy: 0.9960
# Epoch 24/30
# 313/313 [==============================] - 173s 552ms/step - loss: 0.0100 - accuracy: 0.9959 - val_loss: 0.0030 - val_accuracy: 0.9990
# Epoch 25/30
# 313/313 [==============================] - 176s 564ms/step - loss: 0.0183 - accuracy: 0.9941 - val_loss: 0.7898 - val_accuracy: 0.7523
# Epoch 26/30
# 313/313 [==============================] - 177s 564ms/step - loss: 0.0112 - accuracy: 0.9962 - val_loss: 0.0642 - val_accuracy: 0.9743
# Epoch 27/30
# 313/313 [==============================] - 173s 554ms/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.0021 - val_accuracy: 0.9990
# Epoch 28/30
# 313/313 [==============================] - 173s 552ms/step - loss: 0.0128 - accuracy: 0.9959 - val_loss: 0.0080 - val_accuracy: 0.9977
# Epoch 29/30
# 313/313 [==============================] - 175s 558ms/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 0.2375 - val_accuracy: 0.9253
# Epoch 30/30
# 313/313 [==============================] - 176s 561ms/step - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.0949 - val_accuracy: 0.9660

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')
