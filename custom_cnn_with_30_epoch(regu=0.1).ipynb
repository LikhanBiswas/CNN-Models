# %% [markdown]
# <a href="https://colab.research.google.com/github/LikhanBiswas/CNN-Models/blob/main/custom_cnn_with_30_epoch(regu%3D0.1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Aug 26 16:29:50 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Model
from keras import models
import keras
from keras import regularizers

# %%
my_model= models.Sequential()

# %%
# Add first convolutional block
my_model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(215,215,3)))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))

# second block
my_model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2),strides=(2,2), padding='same'))
# third block
my_model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
# fourth block
my_model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
#my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
#fifth block
my_model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
#sixth block
my_model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
#seventh block
my_model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))

# %%
my_model.add(GlobalAveragePooling2D())
# fully connected layer
my_model.add(Dense(64, activation='relu'))
my_model.add(BatchNormalization())
# make predictions
my_model.add(Dense(1, activation='sigmoid'))

# %%
# Show a summary of the model. Check the number of trainable parameters
my_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 215, 215, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 108, 108, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 54, 54, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 27, 27, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 27, 27, 128)       73856
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 27, 27, 128)       147584
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 27, 27, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 256)       295168
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 256)       590080
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 14, 14, 256)       590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 7, 7, 512)         1180160
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 7, 7, 512)         2359808
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                32832
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 7,805,921
# Trainable params: 7,805,793
# Non-trainable params: 128
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(my_model, to_file='model_plot.png', show_shapes=True, show_layer_names=True, dpi = 60)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
es=EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

# save best model automatically
#mc= ModelCheckpoint('/content/drive/MyDrive/extension/custom_cnn.h5', monitor='val_loss', 
                    #mode='min', verbose=1, save_best_only=True)
#cb_list=[es,mc]

# %%
for layer in my_model.layers:
    layer.kernel_regularizer = keras.regularizers.l1_l2(0.1)

# %%
my_model.compile(optimizer='adam', loss='binary_crossentropy', 
                 metrics=['accuracy'])

# %%
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator

# set up data generator
data_generator = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_path = '/content/drive/MyDrive/real vs fake/NEW_TRAIN_10K'
valid_path = '/content/drive/MyDrive/real vs fake/test'

# %%
data_generator = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.1,
                                   zoom_range=0.1,
                                   rotation_range=90,
                                   width_shift_range=0.1,
                                   #fill_mode='wrap',
                                   height_shift_range=0.1,
                                   #channel_shift_range=150.0,
                                   brightness_range=(0.1, 0.5),
                                   vertical_flip=True,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# get batches of training images from the directory
train_generator = data_generator.flow_from_directory(
        '/content/drive/MyDrive/real vs fake/NEW_TRAIN_10K',
        target_size=(215, 215),
        batch_size=32,
        color_mode='rgb',
        class_mode='binary')

# get batches of validation images from the directory
validation_generator = test_datagen.flow_from_directory(
        '/content/drive/MyDrive/real vs fake/test',
        target_size=(215, 215),
        batch_size=32,
        color_mode='rgb',
        class_mode='binary')
# Out:
# Found 10000 images belonging to 2 classes.
# Found 3000 images belonging to 2 classes.

# %%
history = my_model.fit(
        train_generator,
        epochs=30,
        steps_per_epoch=len(train_generator),
        validation_data=validation_generator,
        validation_steps=93)
# Out:
# Epoch 1/30
# 313/313 [==============================] - 7547s 24s/step - loss: 0.2917 - accuracy: 0.8734 - val_loss: 0.1608 - val_accuracy: 0.9378
# Epoch 2/30
# 313/313 [==============================] - 168s 537ms/step - loss: 0.1308 - accuracy: 0.9492 - val_loss: 2.6815 - val_accuracy: 0.6267
# Epoch 3/30
# 313/313 [==============================] - 169s 538ms/step - loss: 0.0612 - accuracy: 0.9791 - val_loss: 3.4944 - val_accuracy: 0.4997
# Epoch 4/30
# 313/313 [==============================] - 168s 537ms/step - loss: 0.0336 - accuracy: 0.9890 - val_loss: 0.7138 - val_accuracy: 0.7601
# Epoch 5/30
# 313/313 [==============================] - 167s 533ms/step - loss: 0.0308 - accuracy: 0.9896 - val_loss: 0.5746 - val_accuracy: 0.7846
# Epoch 6/30
# 313/313 [==============================] - 165s 528ms/step - loss: 0.0220 - accuracy: 0.9934 - val_loss: 0.0271 - val_accuracy: 0.9923
# Epoch 7/30
# 313/313 [==============================] - 168s 537ms/step - loss: 0.0256 - accuracy: 0.9917 - val_loss: 0.1047 - val_accuracy: 0.9724
# Epoch 8/30
# 313/313 [==============================] - 164s 525ms/step - loss: 0.0145 - accuracy: 0.9954 - val_loss: 0.1142 - val_accuracy: 0.9694
# Epoch 9/30
# 313/313 [==============================] - 166s 529ms/step - loss: 0.0194 - accuracy: 0.9935 - val_loss: 0.0327 - val_accuracy: 0.9886
# Epoch 10/30
# 313/313 [==============================] - 164s 525ms/step - loss: 0.0232 - accuracy: 0.9919 - val_loss: 0.2225 - val_accuracy: 0.9170
# Epoch 11/30
# 313/313 [==============================] - 166s 530ms/step - loss: 0.0200 - accuracy: 0.9928 - val_loss: 0.0269 - val_accuracy: 0.9899
# Epoch 12/30
# 313/313 [==============================] - 167s 532ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 1.8784 - val_accuracy: 0.6156
# Epoch 13/30
# 313/313 [==============================] - 167s 535ms/step - loss: 0.0231 - accuracy: 0.9917 - val_loss: 0.0819 - val_accuracy: 0.9738
# Epoch 14/30
# 313/313 [==============================] - 166s 529ms/step - loss: 0.0133 - accuracy: 0.9956 - val_loss: 0.1175 - val_accuracy: 0.9620
# Epoch 15/30
# 313/313 [==============================] - 166s 530ms/step - loss: 0.0318 - accuracy: 0.9889 - val_loss: 0.0210 - val_accuracy: 0.9916
# Epoch 16/30
# 313/313 [==============================] - 167s 535ms/step - loss: 0.0244 - accuracy: 0.9920 - val_loss: 0.0192 - val_accuracy: 0.9913
# Epoch 17/30
# 313/313 [==============================] - 167s 532ms/step - loss: 0.0203 - accuracy: 0.9937 - val_loss: 0.0282 - val_accuracy: 0.9909
# Epoch 18/30
# 313/313 [==============================] - 169s 540ms/step - loss: 0.0162 - accuracy: 0.9947 - val_loss: 0.1079 - val_accuracy: 0.9731
# Epoch 19/30
# 313/313 [==============================] - 168s 537ms/step - loss: 0.0175 - accuracy: 0.9937 - val_loss: 0.0519 - val_accuracy: 0.9808
# Epoch 20/30
# 313/313 [==============================] - 167s 533ms/step - loss: 0.0112 - accuracy: 0.9958 - val_loss: 0.0611 - val_accuracy: 0.9798
# Epoch 21/30
# 313/313 [==============================] - 165s 527ms/step - loss: 0.0147 - accuracy: 0.9946 - val_loss: 0.1205 - val_accuracy: 0.9704
# Epoch 22/30
# 313/313 [==============================] - 165s 529ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.0675 - val_accuracy: 0.9768
# Epoch 23/30
# 313/313 [==============================] - 162s 519ms/step - loss: 0.0164 - accuracy: 0.9940 - val_loss: 0.1628 - val_accuracy: 0.9590
# Epoch 24/30
# 313/313 [==============================] - 166s 530ms/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 0.0109 - val_accuracy: 0.9963
# Epoch 25/30
# 313/313 [==============================] - 167s 535ms/step - loss: 0.0112 - accuracy: 0.9959 - val_loss: 0.0213 - val_accuracy: 0.9929
# Epoch 26/30
# 313/313 [==============================] - 167s 534ms/step - loss: 0.0145 - accuracy: 0.9948 - val_loss: 0.2234 - val_accuracy: 0.9261
# Epoch 27/30
# 313/313 [==============================] - 166s 530ms/step - loss: 0.0125 - accuracy: 0.9967 - val_loss: 0.1813 - val_accuracy: 0.9543
# Epoch 28/30
# 313/313 [==============================] - 165s 528ms/step - loss: 0.0145 - accuracy: 0.9951 - val_loss: 0.0190 - val_accuracy: 0.9936
# Epoch 29/30
# 313/313 [==============================] - 168s 535ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.1664 - val_accuracy: 0.9456
# Epoch 30/30
# 313/313 [==============================] - 166s 531ms/step - loss: 0.0149 - accuracy: 0.9948 - val_loss: 0.0881 - val_accuracy: 0.9768

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')
