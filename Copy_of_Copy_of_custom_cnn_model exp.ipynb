# %% [markdown]
# <a href="https://colab.research.google.com/github/LikhanBiswas/CNN-Models/blob/main/Copy_of_Copy_of_custom_cnn_model%20exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Model
from keras import models
import keras
from keras import regularizers

# %%
my_model= models.Sequential()

# %%
# Add first convolutional block
my_model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(215,215,3)))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))

# second block
my_model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2),strides=(2,2), padding='same'))
# third block
my_model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
# fourth block
my_model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
#my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
#fifth block
my_model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
#sixth block
my_model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))
#seventh block
my_model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
my_model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))
my_model.add(MaxPooling2D((2, 2), strides=(2,2), padding='same'))

# %%
my_model.add(GlobalAveragePooling2D())
# fully connected layer
my_model.add(Dense(64, activation='relu'))
my_model.add(Dense(64, activation='relu'))
my_model.add(BatchNormalization())
# make predictions
my_model.add(Dense(1, activation='sigmoid'))

# %%
# Show a summary of the model. Check the number of trainable parameters
my_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 215, 215, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 108, 108, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 108, 108, 32)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 54, 54, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 27, 27, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 27, 27, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 512)         2359808
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 2, 2, 32)          147488
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 1, 1, 32)          0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 1, 32)          9248
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 1, 1, 32)          0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 1, 1, 64)          18496
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 1, 1, 128)         73856
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 1, 1, 128)         147584
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 1, 1, 128)         147584
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 1, 1, 128)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 1, 1, 256)         295168
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 1, 1, 256)         590080
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 1, 1, 256)         590080
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 1, 1, 512)         1180160
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 1, 1, 512)         2359808
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 1, 1, 512)         2359808
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 1, 1, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                32832
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64)                256
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 15,729,441
# Trainable params: 15,729,313
# Non-trainable params: 128
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(my_model, to_file='model_plot.png', show_shapes=True, show_layer_names=True, dpi = 60)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
#es=EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

# save best model automatically
#mc= ModelCheckpoint('/content/drive/MyDrive/extension/custom_cnn.h5', monitor='val_loss', 
                    #mode='min', verbose=1, save_best_only=True)
#cb_list=[es,mc]

# %%
#x = Flatten()(my_model.output)
#prediction = Dense(1, activation='sigmoid')(x)

# %%
for layer in my_model.layers:
    layer.kernel_regularizer = keras.regularizers.l1_l2(0.01)

# %%
my_model.compile(optimizer='adam', loss='binary_crossentropy', 
                 metrics=['accuracy'])

# %%
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator

# set up data generator
data_generator = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_path = '/content/drive/MyDrive/real vs fake/NEW_TRAIN_10K'
valid_path = '/content/drive/MyDrive/real vs fake/test'

# %%
data_generator = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.1,
                                   zoom_range=0.1,
                                   rotation_range=90,
                                   width_shift_range=0.1,
                                   #fill_mode='wrap',
                                   height_shift_range=0.1,
                                   #channel_shift_range=150.0,
                                   brightness_range=(0.1, 0.5),
                                   vertical_flip=True,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# get batches of training images from the directory
train_generator = data_generator.flow_from_directory(
        '/content/drive/MyDrive/real vs fake/NEW_TRAIN_10K',
        target_size=(215, 215),
        batch_size=32,
        class_mode='binary')

# get batches of validation images from the directory
validation_generator = test_datagen.flow_from_directory(
        '/content/drive/MyDrive/real vs fake/test',
        target_size=(215, 215),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 10000 images belonging to 2 classes.
# Found 3000 images belonging to 2 classes.

# %%
history = my_model.fit(
        train_generator,
        epochs=20,
        steps_per_epoch=len(train_generator),
        validation_data=validation_generator,
        validation_steps=66)
# Out:
# Epoch 1/20
# 313/313 [==============================] - 6621s 21s/step - loss: 0.6935 - accuracy: 0.4980 - val_loss: 0.6931 - val_accuracy: 0.5043
# Epoch 2/20
# 313/313 [==============================] - 521s 2s/step - loss: 0.6933 - accuracy: 0.4922 - val_loss: 0.6932 - val_accuracy: 0.5028
# Epoch 3/20
# 313/313 [==============================] - 270s 865ms/step - loss: 0.6932 - accuracy: 0.5060 - val_loss: 0.6942 - val_accuracy: 0.4929
# Epoch 4/20
# 313/313 [==============================] - 198s 633ms/step - loss: 0.6933 - accuracy: 0.5026 - val_loss: 0.6932 - val_accuracy: 0.5033
# Epoch 5/20
# 313/313 [==============================] - 174s 557ms/step - loss: 0.6933 - accuracy: 0.5044 - val_loss: 0.6931 - val_accuracy: 0.5099
# Epoch 6/20
# 313/313 [==============================] - 166s 532ms/step - loss: 0.6899 - accuracy: 0.5046 - val_loss: 119.4302 - val_accuracy: 0.5123
# Epoch 7/20
# 313/313 [==============================] - 169s 539ms/step - loss: 0.2159 - accuracy: 0.9088 - val_loss: 1.0140 - val_accuracy: 0.6402
# Epoch 8/20
# 313/313 [==============================] - 165s 527ms/step - loss: 0.0819 - accuracy: 0.9687 - val_loss: 0.3446 - val_accuracy: 0.8793
# Epoch 9/20
# 313/313 [==============================] - 165s 526ms/step - loss: 0.0617 - accuracy: 0.9784 - val_loss: 0.0167 - val_accuracy: 0.9938
# Epoch 10/20
# 313/313 [==============================] - 170s 544ms/step - loss: 0.0459 - accuracy: 0.9852 - val_loss: 0.1109 - val_accuracy: 0.9645
# Epoch 11/20
# 313/313 [==============================] - 171s 547ms/step - loss: 0.0342 - accuracy: 0.9886 - val_loss: 0.1686 - val_accuracy: 0.9527
# Epoch 12/20
# 313/313 [==============================] - 171s 547ms/step - loss: 0.0302 - accuracy: 0.9905 - val_loss: 0.7955 - val_accuracy: 0.7969
# Epoch 13/20
# 313/313 [==============================] - 170s 544ms/step - loss: 0.0376 - accuracy: 0.9871 - val_loss: 0.8284 - val_accuracy: 0.8300
# Epoch 14/20
# 313/313 [==============================] - 171s 547ms/step - loss: 0.0300 - accuracy: 0.9891 - val_loss: 0.2625 - val_accuracy: 0.9266
# Epoch 15/20
# 313/313 [==============================] - 170s 542ms/step - loss: 0.0201 - accuracy: 0.9933 - val_loss: 4.1458 - val_accuracy: 0.5071
# Epoch 16/20
# 313/313 [==============================] - 170s 542ms/step - loss: 0.0247 - accuracy: 0.9909 - val_loss: 0.5209 - val_accuracy: 0.8660
# Epoch 17/20
# 313/313 [==============================] - 171s 546ms/step - loss: 0.0208 - accuracy: 0.9931 - val_loss: 0.0740 - val_accuracy: 0.9839
# Epoch 18/20
# 313/313 [==============================] - 170s 544ms/step - loss: 0.0221 - accuracy: 0.9918 - val_loss: 0.0720 - val_accuracy: 0.9811
# Epoch 19/20
# 313/313 [==============================] - 171s 547ms/step - loss: 0.0215 - accuracy: 0.9934 - val_loss: 0.2621 - val_accuracy: 0.9389
# Epoch 20/20
# 313/313 [==============================] - 170s 543ms/step - loss: 0.0279 - accuracy: 0.9908 - val_loss: 3.1356 - val_accuracy: 0.5904

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')
